# %%
print('Sesi part ini data cleaning sudah selesai')
# Out:
# Sesi part ini data cleaning sudah selesai

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
